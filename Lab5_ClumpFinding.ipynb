# %% [markdown]
# # Problem 1:  Generate a Random DNA Sequence

# %%
import random
from time import process_time
import string

t1_start = process_time()
random_integer = random.randint(10,1000)
letters =['A','G','C','T']
random_string = ''

for _ in range(random_integer):
    random_string += (random.choice(letters))
t1_stop = process_time()

print(random_string)
print(len(random_string))
print("Elapsed time:",t1_stop,t1_start)
print("Elapsed time during the whole program in seconds:",t1_stop-t1_start)
# Out:
# ...
# 844
# Elapsed time: 0.875931586 0.875511816
# Elapsed time during the whole program in seconds: 0.0004197699999999305

# %% [markdown]
# # Problem 2: Compute the Hamming Distance Between TwoStrings

# %%
def hamming_distance():
    string1 = "..."
    string2 = "..."
    distance = 0
    L = len(string1)
    for i in range(L):
        # Add 1 to the distance if these two characters are not equal
        if string1[i] != string2[i]:
            distance += 1
    return distance

# %%
example_dist = hamming_distance()
print(example_dist)
# Out:
# 781

# %% [markdown]
# # Problem 3: Find Patterns Forming Clumps in a String

# %%
sequence = input("What is the genomic sequence? ")
k = int(input("What is the length k of each kmer? "))
L = int(input("What is the length of clump L? "))
t = int(input("What is the minimum times t? "))
DNA = str(sequence.upper())
counts = {}

for i in range(0, len(DNA) - k + 1):
	kmer = DNA[i:i + k]
	if kmer in counts:
		counts[kmer] += 1
	else:
		counts[kmer] = 1

frequent = {}

for k in counts:
	if counts[k] >= t:
		frequent[k] = counts[k]

answer = frequent.keys()
output = ' '.join(answer)
print(output)
# Out:
# What is the genomic sequence? ...
# What is the length k of each kmer? 9
# What is the length of clump L? 521
# What is the minimum times t? 18
# GTCATGACC TAATCTTGG CGCACTTTT GTCTGCCGT TCTGCCGTG CTGCCGTGT CTAGTGTAA CCTCCAGTA GGCATGGGC CGACTTTAT CACCGGCGC TGCCGTGTC GCCGTGTCT CCGTGTCTG CGTGTCTGC GTGTCTGCC TGTCTGCCG
